# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
# df.head()

# %%
df.columns
# Out:
# Index(['gender', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'status',
#        'ssc_b_Central', 'ssc_b_Others', 'hsc_b_Central', 'hsc_b_Others',
#        'hsc_s_Arts', 'hsc_s_Commerce', 'hsc_s_Science', 'degree_t_Comm&Mgmt',
#        'degree_t_Others', 'degree_t_Sci&Tech', 'workex_No', 'workex_Yes',
#        'specialisation_Mkt&Fin', 'specialisation_Mkt&HR'],
#       dtype='object')

# %%
cats_col = [col for col in df.columns if df[col].dtype == 'object']
cats_col
# Out:
# ['ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
df = pd.get_dummies(df, columns=['ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation'])
df.head()
# Out:
#    sl_no  gender  ssc_p  hsc_p  degree_p  etest_p  mba_p      status  \
# 0      1       0  67.00  91.00     58.00     55.0  58.80      Placed
# 1      2       0  79.33  78.33     77.48     86.5  66.28      Placed
# 2      3       0  65.00  68.00     64.00     75.0  57.80      Placed
# 3      4       0  56.00  52.00     52.00     66.0  59.43  Not Placed
# 4      5       0  85.80  73.60     73.30     96.8  55.50      Placed
#
#      salary  ssc_b_Central  ...  hsc_s_Arts  hsc_s_Commerce  hsc_s_Science  \
# 0  270000.0          False  ...       False            True          False
# 1  200000.0           True  ...       False           False           True
# 2  250000.0           True  ...        True           False          False
# 3       NaN           True  ...       False           False           True
# 4  425000.0           True  ...       False            True          False
#
#    degree_t_Comm&Mgmt  degree_t_Others  degree_t_Sci&Tech  workex_No  \
# ...

# %%
df = df.drop(columns=['sl_no'])

# %%
df = df.drop(columns=['salary'])

# %%
df.head()
# Out:
#    gender  ssc_p  hsc_p  degree_p  etest_p  mba_p      status  ssc_b_Central  \
# 0       0  67.00  91.00     58.00     55.0  58.80      Placed          False
# 1       0  79.33  78.33     77.48     86.5  66.28      Placed           True
# 2       0  65.00  68.00     64.00     75.0  57.80      Placed           True
# 3       0  56.00  52.00     52.00     66.0  59.43  Not Placed           True
# 4       0  85.80  73.60     73.30     96.8  55.50      Placed           True
#
#    ssc_b_Others  hsc_b_Central  ...  hsc_s_Arts  hsc_s_Commerce  \
# 0          True          False  ...       False            True
# 1         False          False  ...       False           False
# 2         False           True  ...        True           False
# 3         False           True  ...       False           False
# 4         False           True  ...       False            True
#
#    hsc_s_Science  degree_t_Comm&Mgmt  degree_t_Others  degree_t_Sci&Tech  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'status' column
df['status'] = label_encoder.fit_transform(df['status'])

# Display the first few rows to verify

# %%
df.head()
# Out:
#    gender  ssc_p  hsc_p  degree_p  etest_p  mba_p  status  ssc_b_Central  \
# 0       0  67.00  91.00     58.00     55.0  58.80       1          False
# 1       0  79.33  78.33     77.48     86.5  66.28       1           True
# 2       0  65.00  68.00     64.00     75.0  57.80       1           True
# 3       0  56.00  52.00     52.00     66.0  59.43       0           True
# 4       0  85.80  73.60     73.30     96.8  55.50       1           True
#
#    ssc_b_Others  hsc_b_Central  ...  hsc_s_Arts  hsc_s_Commerce  \
# 0          True          False  ...       False            True
# 1         False          False  ...       False           False
# 2         False           True  ...        True           False
# 3         False           True  ...       False           False
# 4         False           True  ...       False            True
#
#    hsc_s_Science  degree_t_Comm&Mgmt  degree_t_Others  degree_t_Sci&Tech  \
# ...

# %%
from sklearn.model_selection import train_test_split


x = df.drop(columns=['status'])
y = df['status']
xtrain, xtest, ytrain, ytest = train_test_split(x,y, random_state=1, test_size=0.2)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

def train_classifiers(X_train, y_train):
    classifiers = {
        'Random Forest': RandomForestClassifier(),
        'SVM': SVC(),
        'Logistic Regression': LogisticRegression(max_iter=1000),
        'K-Nearest Neighbors': KNeighborsClassifier(),
        'Naive Bayes': GaussianNB()
    }
    
    results = {}
    
    for name, clf in classifiers.items():
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_train)
        accuracy = accuracy_score(y_train, y_pred)
        report = classification_report(y_train, y_pred, output_dict=True)
        
        results[name] = {
            'accuracy': accuracy,
            'classification_report': report
        }
    
    return results

# Example usage
# Assuming X_train and y_train are your training data
# X_train, y_train = your_data_split_function()

# Example usage of the function
results = train_classifiers(xtrain, ytrain)

# Print results
for clf_name, metrics in results.items():
    print(f"Classifier: {clf_name}")
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print("Classification Report:")
    print(pd.DataFrame(metrics['classification_report']).transpose())
    print("\n")
# Out:
# Classifier: Random Forest
# Accuracy: 1.0000
# Classification Report:
#               precision  recall  f1-score  support
# 0                   1.0     1.0       1.0     52.0
# 1                   1.0     1.0       1.0    120.0
# accuracy            1.0     1.0       1.0      1.0
# macro avg           1.0     1.0       1.0    172.0
# weighted avg        1.0     1.0       1.0    172.0
#
#
# Classifier: SVM
# Accuracy: 0.8314
# Classification Report:
#               precision    recall  f1-score     support
# 0              0.960000  0.461538  0.623377   52.000000
# 1              0.809524  0.991667  0.891386  120.000000
# accuracy       0.831395  0.831395  0.831395    0.831395
# macro avg      0.884762  0.726603  0.757381  172.000000
# weighted avg   0.855017  0.831395  0.810360  172.000000
#
#
# Classifier: Logistic Regression
# Accuracy: 0.8895
# Classification Report:
#               precision    recall  f1-score     support
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

def train_and_evaluate_classifiers(X_train, y_train, X_test, y_test):
    classifiers = {
        'Random Forest': RandomForestClassifier(),
        'SVM': SVC(),
        'Logistic Regression': LogisticRegression(max_iter=1000),
        'K-Nearest Neighbors': KNeighborsClassifier(),
        'Naive Bayes': GaussianNB()
    }
    
    results = {}
    
    for name, clf in classifiers.items():
        clf.fit(X_train, y_train)
        
        # Predictions and Metrics for Training Data
        y_train_pred = clf.predict(X_train)
        train_accuracy = accuracy_score(y_train, y_train_pred)
        train_report = classification_report(y_train, y_train_pred, output_dict=True)
        
        # Predictions and Metrics for Test Data
        y_test_pred = clf.predict(X_test)
        test_accuracy = accuracy_score(y_test, y_test_pred)
        test_report = classification_report(y_test, y_test_pred, output_dict=True)
        
        results[name] = {
            'train_accuracy': train_accuracy,
            'train_classification_report': train_report,
            'test_accuracy': test_accuracy,
            'test_classification_report': test_report
        }
    
    return results

# Example usage
# Assuming X_train, y_train, X_test, and y_test are your data splits
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Example usage of the function
results = train_and_evaluate_classifiers(xtrain, ytrain,xtest, ytest)

# Print results
for clf_name, metrics in results.items():
    print(f"Classifier: {clf_name}")
    print(f"Training Accuracy: {metrics['train_accuracy']:.4f}")
    print("Training Classification Report:")
    print(pd.DataFrame(metrics['train_classification_report']).transpose())
    print(f"Test Accuracy: {metrics['test_accuracy']:.4f}")
    print("Test Classification Report:")
    print(pd.DataFrame(metrics['test_classification_report']).transpose())
    print("\n")
# Out:
# Classifier: Random Forest
# Training Accuracy: 1.0000
# Training Classification Report:
#               precision  recall  f1-score  support
# 0                   1.0     1.0       1.0     52.0
# 1                   1.0     1.0       1.0    120.0
# accuracy            1.0     1.0       1.0      1.0
# macro avg           1.0     1.0       1.0    172.0
# weighted avg        1.0     1.0       1.0    172.0
# Test Accuracy: 0.8837
# Test Classification Report:
#               precision    recall  f1-score    support
# 0              0.916667  0.733333  0.814815  15.000000
# 1              0.870968  0.964286  0.915254  28.000000
# accuracy       0.883721  0.883721  0.883721   0.883721
# macro avg      0.893817  0.848810  0.865035  43.000000
# weighted avg   0.886909  0.883721  0.880217  43.000000
#
#
# Classifier: SVM
# Training Accuracy: 0.8314
# Training Classification Report:
#               precision    recall  f1-score     support
# ...

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
rf_param_grid = {
    'n_estimators': [100, 200, 300, 400],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}
svm_param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto'],
    'degree': [3, 4, 5]  # For polynomial kernel only
}
lr_param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga']
}

# %%
def tune_random_forest(X_train, y_train):
    rf = RandomForestClassifier()
    grid_search = GridSearchCV(estimator=rf, param_grid=rf_param_grid, cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, grid_search.best_params_
def tune_svm(X_train, y_train):
    svm = SVC()
    grid_search = GridSearchCV(estimator=svm, param_grid=svm_param_grid, cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, grid_search.best_params_

def tune_logistic_regression(X_train, y_train):
    lr = LogisticRegression()
    grid_search = GridSearchCV(estimator=lr, param_grid=lr_param_grid, cv=5, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    return grid_search.best_estimator_, grid_search.best_params_

# %%
# Assume X_train, y_train, X_test, and y_test are your data

# Tuning models
best_rf, rf_params = tune_random_forest(xtrain, ytrain)
best_svm, svm_params = tune_svm(xtrain, ytrain)
best_lr, lr_params = tune_logistic_regression(xtrain, ytrain)

print("Best Random Forest Parameters:", rf_params)
print("Best SVM Parameters:", svm_params)
print("Best Logistic Regression Parameters:", lr_params)

# Evaluating the best models
def evaluate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    print(f"Training Accuracy: {accuracy_score(y_train, y_train_pred):.4f}")
    print("Training Classification Report:")
    print(classification_report(y_train, y_train_pred))
    
    print(f"Test Accuracy: {accuracy_score(y_test, y_test_pred):.4f}")
    print("Test Classification Report:")
    print(classification_report(y_test, y_test_pred))

# Evaluate the tuned models
print("Random Forest:")
evaluate_model(best_rf, xtrain, ytrain, xtest, ytest)

print("SVM:")
evaluate_model(best_svm, xtrain, ytrain, xtest, ytest)

print("Logistic Regression:")
evaluate_model(best_lr, xtrain, ytrain, xtest, ytest)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s[CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
#
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.6s
# ...

# %%
# final model

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# Initialize and train the Random Forest model
rf = RandomForestClassifier(
    bootstrap=True,
    max_depth=30,
    min_samples_leaf=4,
    min_samples_split=5,
    n_estimators=200,
    random_state=42
)
rf.fit(xtrain, ytrain)

# Make predictions and evaluate
rf_train_predictions = rf.predict(xtrain)
rf_test_predictions = rf.predict(xtest)

print("Random Forest:")
print("Training Accuracy:", accuracy_score(ytrain, rf_train_predictions))
print("Training Classification Report:\n", classification_report(ytrain, rf_train_predictions))
print("Test Accuracy:", accuracy_score(ytest, rf_test_predictions))
print("Test Classification Report:\n", classification_report(ytest, rf_test_predictions))
# Out:
# Random Forest:
# Training Accuracy: 0.9418604651162791
# Training Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.83      0.90        52
#            1       0.93      0.99      0.96       120
#
#     accuracy                           0.94       172
#    macro avg       0.95      0.91      0.93       172
# weighted avg       0.94      0.94      0.94       172
#
# Test Accuracy: 0.813953488372093
# Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.53      0.67        15
#            1       0.79      0.96      0.87        28
#
#     accuracy                           0.81        43
#    macro avg       0.84      0.75      0.77        43
# weighted avg       0.83      0.81      0.80        43

# %%
# Initialize and train the SVM model
svm = SVC(
    C=10,
    degree=3,
    gamma='scale',
    kernel='poly'
)
svm.fit(xtrain, ytrain)

# Make predictions and evaluate
svm_train_predictions = svm.predict(xtrain)
svm_test_predictions = svm.predict(xtest)

print("SVM:")
print("Training Accuracy:", accuracy_score(ytrain, svm_train_predictions))
print("Training Classification Report:\n", classification_report(ytrain, svm_train_predictions))
print("Test Accuracy:", accuracy_score(ytest, svm_test_predictions))
print("Test Classification Report:\n", classification_report(ytest, svm_test_predictions))
# Out:
# SVM:
# Training Accuracy: 0.8604651162790697
# Training Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.71      0.76        52
#            1       0.88      0.93      0.90       120
#
#     accuracy                           0.86       172
#    macro avg       0.84      0.82      0.83       172
# weighted avg       0.86      0.86      0.86       172
#
# Test Accuracy: 0.8604651162790697
# Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77        15
#            1       0.84      0.96      0.90        28
#
#     accuracy                           0.86        43
#    macro avg       0.88      0.82      0.83        43
# weighted avg       0.87      0.86      0.85        43

# %%
# Initialize and train the Logistic Regression model
log_reg = LogisticRegression(
    C=10,
    penalty='l2',
    solver='liblinear'
)
log_reg.fit(xtrain, ytrain)

# Make predictions and evaluate
log_reg_train_predictions = log_reg.predict(xtrain)
log_reg_test_predictions = log_reg.predict(xtest)

print("Logistic Regression:")
print("Training Accuracy:", accuracy_score(ytrain, log_reg_train_predictions))
print("Training Classification Report:\n", classification_report(ytrain, log_reg_train_predictions))
print("Test Accuracy:", accuracy_score(ytest, log_reg_test_predictions))
print("Test Classification Report:\n", classification_report(ytest, log_reg_test_predictions))
# Out:
# Logistic Regression:
# Training Accuracy: 0.9011627906976745
# Training Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83        52
#            1       0.93      0.93      0.93       120
#
#     accuracy                           0.90       172
#    macro avg       0.88      0.88      0.88       172
# weighted avg       0.90      0.90      0.90       172
#
# Test Accuracy: 0.9069767441860465
# Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        15
#            1       0.93      0.93      0.93        28
#
#     accuracy                           0.91        43
#    macro avg       0.90      0.90      0.90        43
# weighted avg       0.91      0.91      0.91        43

# %%
# Example new data
new_data = pd.DataFrame({
    'ssc_b': [0],  # Example values
    'hsc_b': [1],
    'hsc_s': [0],
    'degree_t': [1],
    'workex': [1],
    'specialisation': [0]
})

# Ensure the new data is processed in the same way as the training data

# %%
# Predict with Random Forest
rf_predictions = rf.predict(new_data)
print("Random Forest Predictions:", rf_predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 # Predict with Random Forest
# ----> 2 rf_predictions = rf.predict(new_data)
#       3 print("Random Forest Predictions:", rf_predictions)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:823, in ForestClassifier.predict(self, X)
#     802 def predict(self, X):
#     803     """
#     804     Predict class for X.
#     805
#    (...)
#     821         The predicted classes.
#     822     """
# --> 823     proba = self.predict_proba(X)
#     825     if self.n_outputs_ == 1:
#     826         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:865, in ForestClassifier.predict_proba(self, X)
#     863 check_is_fitted(self)
#     864 # Check data
# --> 865 X = self._validate_X_predict(X)
# ...

# %%
df.columns
# Out:
# Index(['gender', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'status',
#        'ssc_b_Central', 'ssc_b_Others', 'hsc_b_Central', 'hsc_b_Others',
#        'hsc_s_Arts', 'hsc_s_Commerce', 'hsc_s_Science', 'degree_t_Comm&Mgmt',
#        'degree_t_Others', 'degree_t_Sci&Tech', 'workex_No', 'workex_Yes',
#        'specialisation_Mkt&Fin', 'specialisation_Mkt&HR'],
#       dtype='object')

# %%
# Example of new data; ensure it has the same columns and preprocessing as the training data
new_data = pd.DataFrame({
    'gender': [0],  # Example values; adjust based on your dataset
    'ssc_p': [67.00],
    'hsc_p': [91.00],
    'degree_p': [58.00],
    'etest_p': [55.0],
    'mba_p': [58.80],
    'ssc_b_Central': [False],
    'ssc_b_Others': [True],
    'hsc_b_Central': [False],
    'hsc_b_Others': [True],
    'hsc_s_Arts': [False],
    'hsc_s_Commerce': [True],
    'hsc_s_Science': [False],
    'degree_t_Comm&Mgmt': [False],
    'degree_t_Others': [False],
    'degree_t_Sci&Tech': [True],
    'workex_No': [True],
    'workex_Yes': [False],
    'specialisation_Mkt&Fin': [True],
    'specialisation_Mkt&HR': [False]
})

# Ensure that the data type of each column matches the training data
new_data = new_data.astype({
    'gender': 'int',
    'ssc_p': 'float',
    'hsc_p': 'float',
    'degree_p': 'float',
    'etest_p': 'float',
    'mba_p': 'float',
    'ssc_b_Central': 'bool',
    'ssc_b_Others': 'bool',
    'hsc_b_Central': 'bool',
    'hsc_b_Others': 'bool',
    'hsc_s_Arts': 'bool',
    'hsc_s_Commerce': 'bool',
    'hsc_s_Science': 'bool',
    'degree_t_Comm&Mgmt': 'bool',
    'degree_t_Others': 'bool',
    'degree_t_Sci&Tech': 'bool',
    'workex_No': 'bool',
    'workex_Yes': 'bool',
    'specialisation_Mkt&Fin': 'bool',
    'specialisation_Mkt&HR': 'bool'
})

# %%
# Predict with Random Forest
rf_predictions = rf.predict(new_data)
print("Random Forest Predictions:", rf_predictions)
# Out:
# Random Forest Predictions: [1]

# %%
# Predict with SVM
svm_predictions = svm.predict(new_data)
print("SVM Predictions:", svm_predictions)
# Out:
# SVM Predictions: [1]

# %%
# Predict with Logistic Regression
log_reg_predictions = log_reg.predict(new_data)
print("Logistic Regression Predictions:", log_reg_predictions)
# Out:
# Logistic Regression Predictions: [1]

# %%
# Assuming 'Placed' = 1 and 'Not Placed' = 0
prediction_labels = {0: 'Not Placed', 1: 'Placed'}

# Convert predictions to labels
rf_labels = [prediction_labels[p] for p in rf_predictions]
svm_labels = [prediction_labels[p] for p in svm_predictions]
log_reg_labels = [prediction_labels[p] for p in log_reg_predictions]

print("Random Forest Prediction Labels:", rf_labels)
print("SVM Prediction Labels:", svm_labels)
print("Logistic Regression Prediction Labels:", log_reg_labels)
# Out:
# Random Forest Prediction Labels: ['Placed']
# SVM Prediction Labels: ['Placed']
# Logistic Regression Prediction Labels: ['Placed']

# %%
import joblib

# Save the models
joblib.dump(rf, 'random_forest_model.pkl')
joblib.dump(svm, 'svm_model.pkl')
joblib.dump(log_reg, 'logistic_regression_model.pkl')
# Out:
# ['logistic_regression_model.pkl']
